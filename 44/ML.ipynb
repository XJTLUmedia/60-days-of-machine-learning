# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")
import tensorflow as tf
from keras.utils import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras import Model, Input
from keras.layers import LSTM, Embedding, Dense
from keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional
from keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
data = pd.read_csv('./LSTM/datav1.4.csv',encoding ='latin1')
data = data.fillna(method = 'ffill')
# Unique words
print(data['Word'].nunique())
print(data['Tag'].nunique())
words = list(set(data['Word'].values))
words.append('ENDPAD')
num_words = len(words)
tags= list(set(data['Tag'].values))
num_tags = len(tags)
num_words, num_tags
# Out:
# 35177
# 17
# (35178, 17)

# %%
class sg(object):
    def __init__(self,data):
        self.n_sent = 1
        self.data = data
        af = lambda s: [(w,p,t) for w,p,t in zip(s['Word'].values.tolist(),
                                                s['POS'].values.tolist(),
                                                s['Tag'].values.tolist())]
        self.grouped = self.data.groupby('Sentence #').apply(af)
        self.sentences = [s for s in self.grouped]
g = sg(data)
s = g.sentences
s[2]
# Out:
# [('Helicopter', 'NN', 'O'),
#  ('gunships', 'NNS', 'O'),
#  ('Saturday', 'NNP', 'B-tim'),
#  ('pounded', 'VBD', 'O'),
#  ('militant', 'JJ', 'O'),
#  ('hideouts', 'NNS', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('Orakzai', 'NNP', 'B-geo'),
#  ('tribal', 'JJ', 'O'),
#  ('region', 'NN', 'O'),
#  (',', ',', 'O'),
#  ('where', 'WRB', 'O'),
#  ('many', 'JJ', 'O'),
#  ('Taliban', 'NNP', 'B-org'),
#  ('militants', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('believed', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('have', 'VB', 'O'),
#  ('fled', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('avoid', 'VB', 'O'),
#  ('an', 'DT', 'O'),
#  ('earlier', 'JJR', 'O'),
#  ('military', 'JJ', 'O'),
#  ('offensive', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('nearby', 'JJ', 'O'),
#  ('South', 'NNP', 'B-geo'),
#  ('Waziristan', 'NNP', 'I-geo'),
#  ('.', '.', 'O')]

# %%
wi = {w: i+1 for i,w in enumerate(words)}
ti = {t: i for i,t, in enumerate(tags)}
wi
# Out:
# {'Aung': 1,
#  'Melanne': 2,
#  'basin': 3,
#  'punishment': 4,
#  'Nations': 5,
#  '608': 6,
#  'Broadcaster': 7,
#  'non-binding': 8,
#  '28,000': 9,
#  'selling': 10,
#  'lntelligence': 11,
#  'arch-rivals': 12,
#  '2,500': 13,
#  'exploit': 14,
#  'fire': 15,
#  '169.9': 16,
#  'post-Castro': 17,
#  '557': 18,
#  'categorized': 19,
#  'generators': 20,
#  'Tomiaki': 21,
#  'Sugiarto': 22,
#  'cheered': 23,
#  'WTO': 24,
#  'Dagger': 25,
#  'Saturday': 26,
#  'Islamist-controlled': 27,
#  'Rostropovich': 28,
#  'welcoming': 29,
#  'abused': 30,
#  '7,200': 31,
#  'Figueredo': 32,
#  'selecting': 33,
#  'resisting': 34,
#  'Sen': 35,
#  'Statements': 36,
#  'sign': 37,
#  'road-building': 38,
#  'Josh': 39,
#  'pastures': 40,
#  '726': 41,
#  'Archaeologists': 42,
#  'Royal-Dutch': 43,
#  'Security': 44,
#  'Carib': 45,
#  'Qantas': 46,
#  '1955': 47,
#  'Saudi-Syrian': 48,
#  'physicist': 49,
#  'abducted': 50,
#  'Turkmens': 51,
#  'punk': 52,
#  'non-believers': 53,
#  'symptoms': 54,
#  'hitch': 55,
#  'Netzarim': 56,
#  '200-mile': 57,
#  'pinions': 58,
#  '1990': 59,
#  'grassroots': 60,
#  'reaction': 61,
#  'Behold': 62,
#  'Qingdao': 63,
#  'third-country': 64,
#  'verdict': 65,
#  'Sopore': 66,
#  'assembly': 67,
#  'Dark': 68,
#  'Anatolian': 69,
#  'aid': 70,
#  '780.47': 71,
#  'saying': 72,
#  'IWC': 73,
#  'Kazakhstani': 74,
#  'crafted': 75,
#  'Donor': 76,
#  'armor-piercing': 77,
#  '5.2': 78,
#  'speculate': 79,
#  'Melville': 80,
#  'appreciate': 81,
#  'arisen': 82,
#  'Nikolai': 83,
#  'revolver': 84,
#  'Guardian': 85,
#  'Stamford': 86,
#  'formerly': 87,
#  'nanny': 88,
#  'analyzed': 89,
#  'Cite': 90,
#  'assigned': 91,
#  'Banbury': 92,
#  'G20': 93,
#  'Bhartiya': 94,
#  'Jaime': 95,
#  'eleginoides': 96,
#  'bauxite': 97,
#  'widely': 98,
#  'Domestic': 99,
#  'Alexander': 100,
#  'Il': 101,
#  'Masser': 102,
#  'Acapulco': 103,
#  'demobilized': 104,
#  'home-grown': 105,
#  'unwilling': 106,
#  'Gaddafi': 107,
#  'Goldman': 108,
#  'al-Faraa': 109,
#  'MONKEY': 110,
#  'Haradinaj': 111,
#  '27-20': 112,
#  'Islam': 113,
#  'detector': 114,
#  '940': 115,
#  'love': 116,
#  'reads': 117,
#  'Critics': 118,
#  'Mustapha': 119,
#  'curling': 120,
#  'figures': 121,
#  'Echeverria': 122,
#  'syndrome': 123,
#  'python': 124,
#  'dune': 125,
#  'Ninety': 126,
#  'pro-government': 127,
#  'involuntarily': 128,
#  'obliged': 129,
#  'historian': 130,
#  'authentic': 131,
#  'offside': 132,
#  'magnitude-7.0': 133,
#  'froze': 134,
#  'answers': 135,
#  'Laboratories': 136,
#  'swaths': 137,
#  'Z': 138,
#  'fundraisers': 139,
#  'rumored': 140,
#  'Levin': 141,
#  'Monkey': 142,
#  'excuse': 143,
#  'Mhawesh': 144,
#  'medium-term': 145,
#  'highest': 146,
#  'militancy': 147,
#  'Sperling': 148,
#  'kind': 149,
#  'Gai': 150,
#  'immigrate': 151,
#  'technocrat': 152,
#  'Eastern': 153,
#  'Geert': 154,
#  'continues': 155,
#  'Surkhanpha': 156,
#  'parmesan': 157,
#  'Swing': 158,
#  'Alstom': 159,
#  '92-years-old': 160,
#  'Panther': 161,
#  'plume': 162,
#  'Italians': 163,
#  'April': 164,
#  'Afghani': 165,
#  'Hammoudi': 166,
#  'Finance': 167,
#  'hindered': 168,
#  'Kourou': 169,
#  'unconventional': 170,
#  'Askar': 171,
#  'sports': 172,
#  'Kunduz': 173,
#  'Waaq': 174,
#  'aegis': 175,
#  'Blige': 176,
#  'Gambira': 177,
#  'Bihar': 178,
#  'smuggling': 179,
#  'icon': 180,
#  'Lone': 181,
#  'Tolima': 182,
#  'Kanow': 183,
#  'Subaru': 184,
#  'break-in': 185,
#  'critically': 186,
#  'Kalfin': 187,
#  're-planted': 188,
#  'concrete': 189,
#  'initialed': 190,
#  'PepsiCo': 191,
#  'Coordinator': 192,
#  'generals': 193,
#  '500-meters': 194,
#  'manipulating': 195,
#  'unimaginably': 196,
#  'undergraduate': 197,
#  'post-civil': 198,
#  'Nangahar': 199,
#  'gloom': 200,
#  'overruns': 201,
#  'blame': 202,
#  'isolate': 203,
#  'ayatollah': 204,
#  'lowland': 205,
#  '5.4': 206,
#  'orphan': 207,
#  'Berkofsky': 208,
#  'counted': 209,
#  'Jones': 210,
#  '10-year-old': 211,
#  'al-Arian': 212,
#  'Gonzalo': 213,
#  'cult': 214,
#  '218': 215,
#  'Coming': 216,
#  'Investment': 217,
#  'Balkan': 218,
#  'Krajina': 219,
#  'benchmark': 220,
#  'Dogg': 221,
#  'expires': 222,
#  'anticipations': 223,
#  'breath': 224,
#  'disadvantage': 225,
#  'Account': 226,
#  'tally': 227,
#  'Bermuda': 228,
#  'cream': 229,
#  'now-defunct': 230,
#  'gypsy': 231,
#  'combination': 232,
#  'Morshed': 233,
#  'suck': 234,
#  'Kimi': 235,
#  'now': 236,
#  'Specialists': 237,
#  'Zelaya': 238,
#  'Caliphate': 239,
#  'uncle': 240,
#  'ready': 241,
#  'push': 242,
#  'river-linking': 243,
#  'IMF-recommended': 244,
#  '207.5': 245,
#  'Shin': 246,
#  'airstrip': 247,
#  '2000': 248,
#  'defeated': 249,
#  'Maori': 250,
#  'Skelleftea': 251,
#  'Tutor': 252,
#  'near-record': 253,
#  'capitalize': 254,
#  'disapproved': 255,
#  'interivew': 256,
#  'Vukovar': 257,
#  'arranged': 258,
#  'poisons': 259,
#  'two-man': 260,
#  'imperative': 261,
#  'damn': 262,
#  'gripped': 263,
#  'ABC': 264,
#  'loads': 265,
#  'Federer-Roddick': 266,
#  'legacy': 267,
#  '7,600': 268,
#  'converged': 269,
#  'showed': 270,
#  'difficult': 271,
#  'proving': 272,
#  'lauded': 273,
#  'West-leaning': 274,
#  'western-style': 275,
#  'journalists': 276,
#  'earmarks': 277,
#  'WNBA': 278,
#  'Usher': 279,
#  'Treasure': 280,
#  'details': 281,
#  'prop': 282,
#  '13.65': 283,
#  'custody': 284,
#  'unauthorized': 285,
#  'Wednesday': 286,
#  'miscommunication': 287,
#  'Hurriyet': 288,
#  'discovering': 289,
#  'recommit': 290,
#  'Qazi': 291,
#  'redistribution': 292,
#  'surpassing': 293,
#  'allege': 294,
#  'wager': 295,
#  'March-May': 296,
#  'breadfruit': 297,
#  'Attempts': 298,
#  'Asou': 299,
#  'depending': 300,
#  'Barak': 301,
#  'PO/PSL': 302,
#  'Madhuri': 303,
#  'Marie-Paule': 304,
#  'sprain': 305,
#  'Fiction': 306,
#  '1644': 307,
#  'guided': 308,
#  'thunderstorms': 309,
#  'regulation': 310,
#  'strayed': 311,
#  'Gleneagles': 312,
#  'Lee': 313,
#  'Chamber': 314,
#  'double-decker': 315,
#  'endorses': 316,
#  'Nest': 317,
#  'monitored': 318,
#  'lamented': 319,
#  '38th': 320,
#  'Mich.-based': 321,
#  'Carmen': 322,
#  'Colom': 323,
#  'pursuant': 324,
#  'Jebel': 325,
#  'Muniz': 326,
#  'levitates': 327,
#  'connections': 328,
#  '27-year': 329,
#  'departed': 330,
#  'Mesut': 331,
#  'Medals': 332,
#  'fuss': 333,
#  'imperialist': 334,
#  'traded': 335,
#  'Wannasathit': 336,
#  'Email': 337,
#  'sectors': 338,
#  'Oct.': 339,
#  'BOYS': 340,
#  'Shawn': 341,
#  'massed': 342,
#  'venomous': 343,
#  'self-rule': 344,
#  'deluxe': 345,
#  'tram': 346,
#  'cell': 347,
#  'Hama': 348,
#  'oil-importing': 349,
#  'Khao': 350,
#  'relation': 351,
#  'two-wheeled': 352,
#  'Afable': 353,
#  'rebut': 354,
#  'Abidine': 355,
#  'firebombing': 356,
#  'pawn': 357,
#  'Aviv': 358,
#  'smothered': 359,
#  'land-for-peace': 360,
#  'betraying': 361,
#  'livelihoods': 362,
#  'Ono': 363,
#  'Celine': 364,
#  'disastrous': 365,
#  'Chol': 366,
#  'install': 367,
#  'highways': 368,
#  'Essebar': 369,
#  'Sonoma': 370,
#  'Suriname': 371,
#  'Andorrans': 372,
#  'collisions': 373,
#  'Service': 374,
#  'toxic': 375,
#  'Moshe': 376,
#  'application': 377,
#  'jumps': 378,
#  '2,800': 379,
#  'loving': 380,
#  'oil-laden': 381,
#  'Yalahow': 382,
#  'plug': 383,
#  'Peter': 384,
#  'Marty': 385,
#  'considers': 386,
#  '135': 387,
#  'FAYYAD': 388,
#  'usually': 389,
#  'Evacuees': 390,
#  'Jean-Tobie': 391,
#  'scribe': 392,
#  'porcelain': 393,
#  'maneuvering': 394,
#  'Rawood': 395,
#  'Chan': 396,
#  'Akhalkalaki': 397,
#  'Klaus': 398,
#  'Section': 399,
#  'Lithuanian': 400,
#  'Lateran': 401,
#  'yen': 402,
#  'collapses': 403,
#  'Press': 404,
#  'non-partisan': 405,
#  'Stefano': 406,
#  'pending': 407,
#  'Bandits': 408,
#  'Kasparov': 409,
#  'Myricks': 410,
#  'French-Colombian': 411,
#  '2.1': 412,
#  'My': 413,
#  'principal': 414,
#  'weather-related': 415,
#  'plundering': 416,
#  'Galloway': 417,
#  'Zebra': 418,
#  'Syrian': 419,
#  'Chiyangwa': 420,
#  'conformity': 421,
#  'Tuo': 422,
#  'Marshal': 423,
#  'oppressive': 424,
#  'poorly': 425,
#  'farmers': 426,
#  'Strategy': 427,
#  'Michaelle': 428,
#  'Vojkovici': 429,
#  'Mutahida': 430,
#  'loosened': 431,
#  'Victor': 432,
#  'Janice': 433,
#  'divorced': 434,
#  'Mitsumi': 435,
#  'EPO': 436,
#  'Fayez': 437,
#  '65-year-old': 438,
#  'terms': 439,
#  'industrial': 440,
#  'plantations': 441,
#  'Muqataa': 442,
#  'accuse': 443,
#  'conservatives': 444,
#  'Departments': 445,
#  'Yoshimasa': 446,
#  'interviewers': 447,
#  'spiraled': 448,
#  '26-year': 449,
#  'annexed': 450,
#  'Him': 451,
#  'Onyango': 452,
#  '11-year': 453,
#  '84': 454,
#  'embryonic': 455,
#  'Friedan': 456,
#  'Lena': 457,
#  '30-year-long': 458,
#  'Escravos': 459,
#  'Sgt.': 460,
#  'animosity': 461,
#  '1784': 462,
#  'counts': 463,
#  'controller': 464,
#  'Ihab': 465,
#  'Luciano': 466,
#  'nutrition': 467,
#  'Shaalan': 468,
#  'Lecturer': 469,
#  'seems': 470,
#  'Immigrants': 471,
#  'Magazine': 472,
#  'Walheim': 473,
#  'cerebral': 474,
#  'others': 475,
#  'confrontation': 476,
#  'weekend': 477,
#  'swollen': 478,
#  'spawning': 479,
#  '255': 480,
#  'abductees': 481,
#  'lawyer': 482,
#  'Marrero': 483,
#  'reported': 484,
#  'tensions': 485,
#  'ejected': 486,
#  'Anat': 487,
#  'Aftab': 488,
#  'Much': 489,
#  'streaming': 490,
#  'Taliban-dominated': 491,
#  'Natanz': 492,
#  'Sugarcane': 493,
#  'Indonesians': 494,
#  'Counter-Terrorism': 495,
#  'karate': 496,
#  'minimize': 497,
#  'Sarabjit': 498,
#  'Taiwo': 499,
#  'Sometimes': 500,
#  '257': 501,
#  'Peoples': 502,
#  'Taha': 503,
#  'cabinet': 504,
#  'activist-journalist': 505,
#  'pro-Shiite': 506,
#  'MILF': 507,
#  'sowing': 508,
#  'Organiation': 509,
#  'shaking': 510,
#  'workload': 511,
#  'chosen': 512,
#  'Stiff': 513,
#  'idols': 514,
#  'Merimee': 515,
#  'Kaesong': 516,
#  'Iraqi-American': 517,
#  '1958': 518,
#  'marines': 519,
#  'sandy': 520,
#  'Mauritius': 521,
#  'time': 522,
#  'Cameron': 523,
#  'deal': 524,
#  '700': 525,
#  'Brazzaville': 526,
#  'downpours': 527,
#  'defendants': 528,
#  'agonies': 529,
#  'flattened': 530,
#  'ore': 531,
#  'caretaker': 532,
#  'Henghameh': 533,
#  'accreditation': 534,
#  'matter': 535,
#  'Pontchartrain': 536,
#  'Ekmeleddin': 537,
#  'disarmament': 538,
#  'Novakatkan': 539,
#  'Gafir': 540,
#  'crying': 541,
#  'Sofia': 542,
#  'defies': 543,
#  'Jason': 544,
#  'Privert': 545,
#  'Finnish': 546,
#  'Fakhar': 547,
#  'Redknapp': 548,
#  '1948': 549,
#  'eradication': 550,
#  'AUNG': 551,
#  'uranium-enriching': 552,
#  'join': 553,
#  'PET': 554,
#  'horror': 555,
#  'span': 556,
#  'Momammad': 557,
#  'calm': 558,
#  'Moderate': 559,
#  'SCHROEDER': 560,
#  'Emerli': 561,
#  'Olmo': 562,
#  'outperformed': 563,
#  'Francisco-based': 564,
#  'snatch': 565,
#  'backtrack': 566,
#  '1215': 567,
#  'Solaiman': 568,
#  'tolerating': 569,
#  'battles': 570,
#  'humanely': 571,
#  '1718': 572,
#  'condemned': 573,
#  'Star': 574,
#  'deserts': 575,
#  'somewhere': 576,
#  'Wessels': 577,
#  'Hezbollah-led': 578,
#  'eight-man': 579,
#  'post-monsoon': 580,
#  'fish': 581,
#  'culled': 582,
#  'Yu': 583,
#  'banditry': 584,
#  'layoffs': 585,
#  'blanked': 586,
#  'mount': 587,
#  'on-the-ground': 588,
#  'nighttime': 589,
#  'cremation': 590,
#  'Adre': 591,
#  'Symonds': 592,
#  'mourners': 593,
#  'Hoshyar': 594,
#  'informer': 595,
#  'indicated': 596,
#  'stabilizing': 597,
#  'compares': 598,
#  'Fyodor': 599,
#  'Kousalyan': 600,
#  'Registry': 601,
#  'Vices': 602,
#  'spoke': 603,
#  'resource': 604,
#  'centers': 605,
#  'contractual': 606,
#  '29,799': 607,
#  'exercises': 608,
#  'Commandos': 609,
#  'wreaked': 610,
#  'imagine': 611,
#  'commend': 612,
#  'Valbuena': 613,
#  'IEDs': 614,
#  'CBO': 615,
#  'SEE': 616,
#  'aggravating': 617,
#  'grain-field': 618,
#  'Seche': 619,
#  'beast': 620,
#  'intruded': 621,
#  'determination': 622,
#  'repeal': 623,
#  '1938': 624,
#  'rounder': 625,
#  'Murshidabad': 626,
#  'Terrorism': 627,
#  'third-seeded': 628,
#  'BULL': 629,
#  '72-year-old': 630,
#  'Banda': 631,
#  'patriotic': 632,
#  'exhort': 633,
#  'cocaine': 634,
#  'SANA': 635,
#  'Komuri': 636,
#  'Jolie': 637,
#  'Erasmus': 638,
#  '786': 639,
#  'Alias': 640,
#  'al-Watan': 641,
#  'biological': 642,
#  'loss': 643,
#  '3-billion': 644,
#  'leaks': 645,
#  'batsmen': 646,
#  'Espino': 647,
#  'Asghari': 648,
#  'war-crimes': 649,
#  'Celtic': 650,
#  '6.9': 651,
#  'flapped': 652,
#  'Delhi-based': 653,
#  'mountain': 654,
#  'Abdallah': 655,
#  'midfield': 656,
#  'ITU': 657,
#  'AN': 658,
#  'legalize': 659,
#  'persecuting': 660,
#  'disruptions': 661,
#  '1,70,000': 662,
#  'power-sharing': 663,
#  'handed': 664,
#  'inquired': 665,
#  'drug-combination': 666,
#  'Sarawak': 667,
#  'win-loss': 668,
#  'assume': 669,
#  'Exchange': 670,
#  'charging': 671,
#  'satisfying': 672,
#  'pre-storm': 673,
#  'Cho': 674,
#  'absentia': 675,
#  'Yorker': 676,
#  'download': 677,
#  'Badawi': 678,
#  'infiltrators': 679,
#  'Ass': 680,
#  'Little': 681,
#  'Ohio': 682,
#  'tossed': 683,
#  'label': 684,
#  'coincides': 685,
#  'frontline': 686,
#  'militant-appointed': 687,
#  'bedroom': 688,
#  'Perry': 689,
#  'KFM': 690,
#  'recorder': 691,
#  'Hassan': 692,
#  'center': 693,
#  'Lindy': 694,
#  'cyclist': 695,
#  'uncensored': 696,
#  'Rizvan': 697,
#  'airline': 698,
#  'Hemingway': 699,
#  'web': 700,
#  'sympathetic': 701,
#  'Naushki': 702,
#  'Cauvin': 703,
#  'encephalopathy': 704,
#  'OECD': 705,
#  'Zablocki': 706,
#  '4,27,000': 707,
#  'counternarcotics': 708,
#  'three-day': 709,
#  'injuries': 710,
#  'Dolphins': 711,
#  'American-made': 712,
#  'doctrine': 713,
#  'overheating': 714,
#  'falling': 715,
#  'unemployed': 716,
#  'fast-track': 717,
#  'Hajem': 718,
#  'Akhtar': 719,
#  '6,000-meter': 720,
#  'strangled': 721,
#  'Hurriyat': 722,
#  'anniversary': 723,
#  'los': 724,
#  'pitching': 725,
#  'launcher': 726,
#  'why': 727,
#  'Dacic': 728,
#  'underway': 729,
#  'Tarulovski': 730,
#  'Vintsuk': 731,
#  'exclusively': 732,
#  'Meshaal': 733,
#  'Jaques': 734,
#  'daytime': 735,
#  'united': 736,
#  'Bahonar': 737,
#  'whaling': 738,
#  'non-Jewish': 739,
#  'Luay': 740,
#  'exposure': 741,
#  'light': 742,
#  'Outmigration': 743,
#  'Memoir': 744,
#  'Blatter': 745,
#  'repairs': 746,
#  'managing': 747,
#  'sailor': 748,
#  'Safina': 749,
#  'Remote': 750,
#  'Miyazaki': 751,
#  'inclusion': 752,
#  'subdue': 753,
#  'decorations': 754,
#  'Highways': 755,
#  'speeding': 756,
#  'toddler': 757,
#  'marriages': 758,
#  'snag': 759,
#  'questions': 760,
#  'line-item': 761,
#  'intending': 762,
#  'thorn': 763,
#  'Interim': 764,
#  'Inspection': 765,
#  'sweetened': 766,
#  'convicted': 767,
#  'Johnson': 768,
#  'papacy': 769,
#  'Palestinian-claimed': 770,
#  'beach': 771,
#  'shielded': 772,
#  'tree': 773,
#  'modern': 774,
#  'Tribunal': 775,
#  'newly-built': 776,
#  'Jaffer': 777,
#  'superba': 778,
#  'Cavaliers': 779,
#  'anti-malaria': 780,
#  'villas': 781,
#  'Volchkova': 782,
#  'youth': 783,
#  'negotiating': 784,
#  'implementing': 785,
#  'Samuels': 786,
#  'mark': 787,
#  'Measles': 788,
#  'deserter': 789,
#  'Ugandan': 790,
#  'confronted': 791,
#  'odd': 792,
#  'Malaysian-led': 793,
#  'subsurface': 794,
#  'albums': 795,
#  '2004': 796,
#  'Mexicali': 797,
#  'swooped': 798,
#  'Razali': 799,
#  'Malenchenko': 800,
#  'Egyptian-owned': 801,
#  'refrigerator': 802,
#  'Ogaden': 803,
#  'reneged': 804,
#  'tariff': 805,
#  'aiding': 806,
#  'popularity': 807,
#  '39': 808,
#  'Polynesians': 809,
#  'incest': 810,
#  'Liberty': 811,
#  'rolling': 812,
#  'Sylvester': 813,
#  'Cartago': 814,
#  'force-fed': 815,
#  'al-Uthmani': 816,
#  'predicting': 817,
#  'strengthening': 818,
#  'Vioxx': 819,
#  'expectation': 820,
#  'Trondheim': 821,
#  'Madrid': 822,
#  'provision': 823,
#  'Rafidain': 824,
#  'predominantly': 825,
#  'Munich': 826,
#  'scandalized': 827,
#  'loosely': 828,
#  'rating': 829,
#  'MNJ': 830,
#  'rubella': 831,
#  'midwestern': 832,
#  'Abul': 833,
#  'ultimate': 834,
#  'consitutional': 835,
#  'contrasts': 836,
#  'Merajudeen': 837,
#  'Turkman': 838,
#  '1,200': 839,
#  'Djokovic': 840,
#  'Montana': 841,
#  'Beijing': 842,
#  'outset': 843,
#  'Challenges': 844,
#  'nano-technology': 845,
#  'state-funded': 846,
#  'market-oriented': 847,
#  'Ecuadorian': 848,
#  'be': 849,
#  'Hanssen-Bauer': 850,
#  'Asia-Oceania': 851,
#  'maternity': 852,
#  'Kolok': 853,
#  'estate': 854,
#  'Religious': 855,
#  'cheaply': 856,
#  'Edel': 857,
#  'disbarred': 858,
#  'Busan': 859,
#  'disagreements': 860,
#  'classroom': 861,
#  'translation': 862,
#  'Bad': 863,
#  'Bole': 864,
#  'Hamas': 865,
#  'squeeze': 866,
#  'Point': 867,
#  'wheelchairs': 868,
#  'trend': 869,
#  'advisor': 870,
#  '800': 871,
#  '57': 872,
#  'Duncan': 873,
#  'Haleh': 874,
#  'parliament': 875,
#  'Strikes': 876,
#  'Initially': 877,
#  'Challenger': 878,
#  'cannons': 879,
#  'constrain': 880,
#  'Alekseyeva': 881,
#  'tactic': 882,
#  'trapped': 883,
#  'Scorpion': 884,
#  'Murat': 885,
#  'exported': 886,
#  'Zabayda': 887,
#  '1946': 888,
#  'Biotechnology': 889,
#  'Hajj': 890,
#  'sanctioned': 891,
#  'Rating': 892,
#  'Sudan': 893,
#  'wild-boar': 894,
#  'Schulz': 895,
#  'elderly': 896,
#  'conquest': 897,
#  'gall': 898,
#  'Demand': 899,
#  'Raikkonen': 900,
#  'Colchis': 901,
#  'Demirel': 902,
#  'rid': 903,
#  'Obita': 904,
#  'Pan-Africa': 905,
#  'basing': 906,
#  'wielding': 907,
#  'interruption': 908,
#  'Khamis': 909,
#  'watermelons': 910,
#  'emitted': 911,
#  'overshadows': 912,
#  'al-Haidari': 913,
#  'Bloemfontein': 914,
#  'sultanate': 915,
#  'emancipation': 916,
#  'mudslides': 917,
#  'Sunni': 918,
#  'rippled': 919,
#  '140': 920,
#  'Righteous': 921,
#  'Route': 922,
#  'Singur': 923,
#  'forefront': 924,
#  'Rezaei': 925,
#  'Moken': 926,
#  'chipmaker': 927,
#  'football': 928,
#  'corporations': 929,
#  'helping': 930,
#  'transactions': 931,
#  'divided': 932,
#  'Crittercam': 933,
#  'Australian': 934,
#  'inflows': 935,
#  'ghettos': 936,
#  'advising': 937,
#  'Egyptian-sponsored': 938,
#  'Jimmy': 939,
#  'cafe': 940,
#  'Hashim': 941,
#  'Nogaideli': 942,
#  'Wipha': 943,
#  'skyrocketed': 944,
#  'dehydration': 945,
#  'masterminds': 946,
#  'credited': 947,
#  'Gongga': 948,
#  'Sgorbati': 949,
#  'Russian-speaking': 950,
#  'Panamanian': 951,
#  '1860s': 952,
#  'USSR': 953,
#  'devised': 954,
#  '129': 955,
#  'legalizing': 956,
#  'Gulf-area': 957,
#  'hedge': 958,
#  'fodder': 959,
#  'Acosta': 960,
#  'Truck': 961,
#  '350-58': 962,
#  'malpractice': 963,
#  'loans': 964,
#  'outcome': 965,
#  'Quoting': 966,
#  'marine-': 967,
#  'policy-setting': 968,
#  'Hanegbi': 969,
#  'considerable': 970,
#  'representative': 971,
#  'establishes': 972,
#  'Counter-terrorism': 973,
#  'Seiken': 974,
#  'fading': 975,
#  'harming': 976,
#  'sedentary': 977,
#  '3rd': 978,
#  'dens': 979,
#  'Cambridge': 980,
#  'present-day': 981,
#  '558-page': 982,
#  'Haruna': 983,
#  'Botanical': 984,
#  'when': 985,
#  'occupied': 986,
#  'perilous': 987,
#  'Thad': 988,
#  'Gerard': 989,
#  'al-Youm': 990,
#  'stymied': 991,
#  'weakest': 992,
#  'Slovakian': 993,
#  'Dahuk': 994,
#  'surveillance': 995,
#  'non-aligned': 996,
#  'consult': 997,
#  'assisted': 998,
#  'avid': 999,
#  'ca.': 1000,
#  ...}

# %%
ml = 50
X= [[wi[w[0]] for w in s ] for s in s]
X = pad_sequences(maxlen=ml,sequences = X,padding ='post',value = num_words-1)
y= [[ti[w[2]] for w in s ] for s in s]
y = pad_sequences(maxlen=ml,sequences = y,padding ='post',value = ti["O"])
y = [to_categorical(i,num_classes = num_tags) for i in y]
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=1)

# %%
input_word = Input(shape=(ml,))
m = Embedding(input_dim = num_words, output_dim = ml,input_length = ml)(input_word)
m= SpatialDropout1D(0.1)(m)
m = Bidirectional(LSTM(units=100, return_sequences = True, recurrent_dropout =0.1))(m)
out= TimeDistributed(Dense(num_tags,activation = 'softmax'))(m)
m = Model(input_word,out)
m.summary()
m.compile(loss='mse', optimizer='adam')
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 50)]              0
#
#  embedding_2 (Embedding)     (None, 50, 50)            1758900
#
#  spatial_dropout1d_2 (Spatia  (None, 50, 50)           0
#  lDropout1D)
#
#  bidirectional_2 (Bidirectio  (None, 50, 200)          120800
#  nal)
#
#  time_distributed_2 (TimeDis  (None, 50, 17)           3417
#  tributed)
#
# =================================================================
# Total params: 1,883,117
# Trainable params: 1,883,117
# Non-trainable params: 0
# _________________________________________________________________

# %%
es= EarlyStopping(monitor='val_accuracy',patience=1,verbose=0,mode='max',restore_best_weights=False)
cb = [PlotLossesCallback(),es]
h = m.fit(
    x_train, np.array(y_train),
    validation_split = 0.2,
    batch_size=32,
    epochs=3,
    verbose = 1
)
# Out:
# Epoch 1/3
# 1080/1080 [==============================] - 58s 51ms/step - loss: 0.0049 - val_loss: 0.0020
# Epoch 2/3
# 1080/1080 [==============================] - 69s 64ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 3/3
# 1080/1080 [==============================] - 56s 52ms/step - loss: 0.0011 - val_loss: 0.0013

# %%
m.evaluate(x_test,np.array(y_test))
# Out:
# 150/150 [==============================] - 3s 21ms/step - loss: 0.0014
# 0.00135014986153692
